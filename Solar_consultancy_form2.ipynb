# %%
# !pip install weasyprint faker PyPDF2 reportlab pdfrw

# %%
from faker import Faker
import random
from weasyprint import HTML
from PIL import Image
import os
import csv
import base64

fake = Faker('en_AU') # Localize to Australia
location_type = "farm"
location_type = "residential home"
location_type = "tourist lodge"
location_type = "communication centre"
#location_type = "local workshop"

# Dictionary of typical AC and DC loads with their power in watts and usage in minutes



sentences = [
"Just a heads up that our house runs on a tanks for water supply. Let me know if you need access to water while doing the site assessment or installation.",
"We have some machinery and livestock equipment stored in one of the sheds. Let me know if you need any space to do staging during the work.",
"Are there any rebates or government incentives available right now to help cover the upfront costs?",
"What is the warranty period on the solar panels and other system components?",
"What should I do in case of a system fault or outage when you're not available to assist?",
"After the system is set up, will you provide training on basic maintenance and troubleshooting I may need to do as the homeowner?",
"A few areas on the roof can be a bit tricky to access safely. Let me know if you need me to set up any temporary staging or ladders.",
"What are your estimated timelines for a site inspection, providing a formal quote, and completing an installation if we go ahead?",
"There is no shade over the best areas for the solar panels. Will this affect performance at all?",
"Are there any financing options if paying upfront isn't possible, such as a loan through your company or a third party?",
"What should I do in an emergency situation like a bushfire if an evacuation is required? Will the solar system shut down automatically?",
"We have some rickety old boardwalks around the property that are easy to miss - let me know if you need help navigating them safely.",
"What tipoif access/wiring would be required through the house roof for an optimal setup? We'd prefer minimizing penetrations wherever possible.",
"Please call ahead on the day you plan to visit - our mobile reception is patchy and I may need to open/close gates for you.",
"The property is only accessible by a long unsealed road - do you have a high clearance vehicle that can manage after heavy rain?",
"We want to future-proof the system for potential EV charging - can the setup accommodate that easy upgrade down the track?",
"What arrangements do you recommend for system monitoring and maintenance post-install to maximize performance over the long run?",
"A few of our farm dogs can be territorial with strangers. I'll keep them inside during your visit but just a heads up in case you see or hear them.",
"What payment schedule do you recommend - pay upfront, financed amount over time, or prepaid maintenance contract?",
"There's an old water tank up on poles near the house that could potentially support some extra solar panels. Can you assess if it's structurally suitable?",
"Feel free to use the hose tap around the side of the house for drinking water etc. Just turn it off when you're done please.",
"After installation, will you provide training so I know how to do basic troubleshooting or what maintenance is required? I want to care for the system myself as much as possible.",
"A few areas of the roof havecomments old tiles/screws that may need replacing before solar can be installed. Do you perform any necessary repairs as part of the package?",
"What warranties and service response times are included if issues arise down the track? We want peace of mind.",
"Let me know if you need me to开 the top paddock gate for vehicle access - it's a bit stiff to open.",
"Our property boundary fences are in varying condition. Please stay well clear just in case of damage oranimals getting out.",
"The solar panels will be clearly visible from the house. Do you have any options with more aesthetic panel designs? Appearance is also a priority for us.",
"Is there an option to pay for the system upfront with finance or via a low interest loan? Funds are tight currently.",
"What maintenance and warranty package do you recommend for optimum system performance long term?",
"Feel free to park on the grass - it's pretty hardy and recovers quickly from vehicle tires.",
"The landline phone has a tedious dial tone. Is there another number I can use to contact you directly if needed?",
"How do your solar panels perform in high winds/storms? We occasionally get some wild weather out here.",
"After installation, can you provide training so my family knows basic system care like cleaning the panels etc? We want to be self-sufficient long term.",
"A few areas of the roof get moss/lichen buildup after rains - will this impact the solar installation or performance at all?",
"What recycling/responsible disposal processes do you recommend for the system when it reaches end of life many years from now?",
"Feel free to bring your drone if it helps with site inspection - just be mindful of the livestock.",
"What level of monitoring and remote access capabilities does the system have? I want to check in remotely if needed.",
"Some roof panels are rusted through - can this be factored into the installation quote?",
"We want to minimize the aesthetic impact as much as possible. Do you have any panel or mounting options that help the system blend in visually? Appearance is important to us long term.",
"Is there an option to add more panels/battery capacity later on if our needs increase over time? I want flexibility to scale the system.",
"What types of livestock or farm machinery could potentially damage the system that I should be aware of/plan for?",
"Feel free to use our hose/tap for washing hands etc. Just turn off securely when finished.",
"How will interruptions to the grid supply (like planned blackouts) affect the hybrid solar/battery system?",
"What safety features do the panels/inverter have to withstand things like hail or falling tree branches we sometimes see?",
"We get the occasional summer storm - can the system be installed to withstand high winds without needing replacement/repairs? Peace of mind is important.",
"Is there an option to pay for the system in smaller installments over several years rather than one lump sum?",
"What type of system monitoring and remote access is included? I may want to check in or troubleshoot from the city when away.",
"How resistant are the panels, wiring etc to potential wildlife issues like possums or birds nesting?",
"What processes do you have in place for warranty repairs or servicing given the remote location? Response times are important to us.",
"A few areas of the roof are a bit tricky to access safely - can temporary staging or ladders be provided if needed?",
"Is there an option to include an electric vehicle charger as part of the installation? We're considering an EV.",
"What is your contingency plan in case the truck gets bogged/breaks down while on our property? Access can be difficult.",
"Please park near the shed - it's a bit of a hike to the house from there but undercover if it rains.",
"How will potential future transmission line upgrades by the energy company affect a hybrid solar/generator system?",
"Are there any government rebates or incentives we could take advantage of right now? Looking to minimize costs.",
"After installation, can you provide training on basic system maintenance - I want to care for it ourselves as much as possible long term.",
"What assessments (e.g. roof integrity) need to be done before installing to ensure it's suitable and safe long-term?",
"Can an electric car charger be factored into the quote? We're considering an EV.",
"How resistant is the system to extreme heat/bushfire conditions we sometimes experience? Safety is important.",
"What payment options are available e.g. paying it off over 5 years through our power bills? Flexibility is useful.",
"Please park under the large gumtree - it provides good shade on hot days.",
"After installation, can you supply manuals and training so we know how to do regular basic system checks ourselves?",
"What assessment of the property and farm infrastructure (e.g. power poles) is required to identify any upgrades needed before installing solar?",
"Will the system integrate with our existing generator for backup power needs? Reliability is key.",
"How do the panels hold up against hail storms we occasionally get? Durability matters.",
"Can an inspection and quote be provided for both roof mount and ground mount system options? Want to consider all options.",
"After installation, can you provide training for regular maintenance like cleaning panels and checking connections ourselves? We want to be self-sufficient long term owners.",
"What sorts of warranties and service level agreements are included to provide peace of mind long term?",
"A few sections of roof are a bit tricky to access safely - can temporary staging or ladders be provided if needed?",
"How resistant is the system, wiring etc to potential wildlife issues like possums, echidnas or birds nesting? Durability is key out here.",
"What arrangements/response times are in place for warranty repairs given our remote location? Reliability matters.",
"How do the panels cope with dust? It can get very dusty and dirty out here during dry spells.",
"Will you need vehicular access to multiple areas of the property for assessment/installation? Let me know if any gates/tracks need opening.",
"What sort of ongoing system monitoring is included to pick up any issues early? Preventative care is best.",
"Can the system be configured to work with an electric fence setup to contain livestock?",
"After installation, will you provide training for the family so we can perform basic panel cleaning and system checks ourselves long term?"
]

suggestions = [
"The open area just south of the house would be ideal for laying out the solar panels. It gets full sun exposure and is relatively flat and clear of trees.",
"We have about a 1000 square foot patch of land behind the barn that wouldn't require mounting the panels on the roof. It seems like a perfect spot given it's close proximity to the house as well. ",
"There's a grassy field adjacent to the property that we think would work well for a ground-mount solar array. It's a nice wide-open space with plenty of room for the panels and equipment.",
"The yard on the north side of the house doesn't see much use and would provide a suitable location for ground-mounted solar panels. It's an easy run to tie them back to the electrical panel inside.",
"We've identified about half an acre behind the house that we could clear and prepare for a ground-level solar installation. It's flat and gets full sun so it seems well-suited for the job.",
"There's an empty lot near the driveway that would accommodate the panels without any obstructions. Being so close to the house, it would simplify the wiring and siting permissions.",
"We have a small grazing paddock just west of the property that would work for the solar system. It's within easy cable distance and avoids using precious roof space.",
"There's a grassy area beside the garden that no longer gets much sunshine due to new tree growth. It seems perfect for repurposing with solar panels.",
"The side field gets direct sunlight all afternoon and morning. Plenty of room there to lay out panels without interfering with other property uses.",
"We've staked out an open spot behind the barn that should give the solar panels the space they need without blocking any views.",
"An unused part of the front paddock that faces north would situate the panels nicely without needing complicated racking on the roof.",
"There's an overgrown patch near the firewood shelter that would be simple to clear out and utilize constructively with a ground installation.",
"We have an empty lot adjacent to the windmill that wouldn't require tall mounting structures or heavy shading from trees.",
"A level area beside the driveways provides ample uncovered space to take advantage of direct sunlight. ",
"A previously disturbed patch behind the animal pens is an ideal candidate for repurposing with a solar array.",
"A south-facing section of pasture that isn't used for grazing would absorb sunlight efficiently without conflicting with farm operations.",
"An open level plot beyond the machinery shed would allow the panels to be situated without obstacles in a single aspect direction.",
"An unused section at the far end of the north paddock is an obvious choice, being clear, accessible, and exposed to the sun.",
"There's an overgrown area near the windbreak trees that's the perfect size and orientation for a ground-level solar installation.",
"An open southwest-facing slope below the barn provides optimal sun exposure and would be easy to level for the arrays.",
"An idle grassy lot by the livestock enclosure would take advantage of full sun with simple due south alignment.",
"An empty northeast-facing portion of the side field is well-situated to capture morning sun without visual or shading obstacles.",
"A disused patch behind the shearers' quarters receives full sun and has handy electrical service already at the property line.",
"An underutilized plot across from the garden shed is well-positioned to harness the sun without conflicts with other land use needs.",
"The old silage area by the cattle yard no longer serves its purpose and would welcome the solar panels with its open exposure.",
"An open southwest facing area below the tree line would be ideally positioned to take full advantage of sunlight.",
"A cleared portion of back pasture that faces north has level ground ready for the solar installation.",
"An unused hillside paddock that's situated for direct sun exposure presents itself as an optimal location.",
"An overgrown stretch behind the chicken coop is well situated and could be conveniently repurposed.",
"An idle parcel adjacent to the access road receives ample sun and could easily be prepared for the solar farm.",
"A disused plot behind the equipment shed has direct sun exposure and is conveniently situated next to power lines.",
"An open southeast-facing slope below the olive grove would capture morning and afternoon sunlight efficiently.",
"An unused grazing area above the vineyard is well positioned to take full advantage of solar gain without interfering with operations.",
"The old composting site below the gardens no longer serves its purpose and has space for effective solar production.",
"An empty northwest-facing field above the seasonal creek is perfectly aligned for forenoon sun without obstructing meadows.",
"A scrubby northeast corner of the bottom paddock could easily host the solar panels in full sun, out of the flood zone.",
"An unused patch behind the seasonal worker cabins has ample sunlight and room for an off-grid solar installation.",
"A disused sheep sorting yard above the shearing shed is well-oriented for solar and has existing electric fencing nearby.",
"An open south-facing plot beyond the bush turkey run receives all-day illumination without interfering with wildlife.",
"An idle slope below the bushfire shed captures optimal sun and has convenient access via the back access track.",
"The old milking parlor site is well-lit and leveled already for solar, with room for battery storage.",
"An open north-facing field above the seasonal creek has direct sunlight and hydro works powerlines close by.",
"An empty patch along the east fence line below the cottage is cleared and receives full sun exposure each day.",
"The old vegetable garden no longer in use is situated perfectly for solar panels facing due north.",
"Scrubby overgrown flats behind the machinery shed welcome solar with their direct sun and proximity to electrical lines.",
"The west-facing slope behind the glasshouse collects ample sunlight throughout the day without obstructing views.",
"An unused grazing area along the southern boundary is open and exposed for effective solar energy generation.",
"Level ground beside the front gate is inconspicuous yet optimized for sun and brings panels close to the main circuits.",
"An idle parcel near the entrance to the back paddocks receives full sun and requires minimal leveling works.",
"A patch below the plantation that used to be an orchard is well-lit and could host the solar farm out of sight.",
"The old sheep dip site situated beside the seasonal creek gets strong sun exposure and has plumbing services available.",
"Overgrown lowlands beyond the machinery depot catch the morning and evening rays without disrupting farm operations.",
"A west-facing embankment behind the machinery shed makes good use of vacant land in a sunny private location.",
"Empty flats near the southern fence line receive abundant sunlight throughout the day next to the livestock run.",
"An unused north-facing field adjacent to the seasonal worker housing would be perfectly positioned to take advantage of sunlight without interfering with other activities.",
"A level area at the northern edge of the upper pasture offers attractive sun exposure and is accessible via the back access road.",
"A disused plot near the western property boundary receives strong afternoon sun exposure and has transmission lines within wiring distance.",
"An open southwest-sloping section below the barn is ideally oriented and located for solar production without conflicts.",
"An overgrown area beyond the seasonal vegetable garden welcomes solar setup to utilize the land with its sunny aspect.",
"Scrubby flats near the eastern fence line are well-lit and situated for a solar farm above the floodplain.",
"Level ground next to the cattle yards is practical for an installation that avoids excessive racking or shading interactions.",
"An open northeast-facing stretch behind the machinery depot could readily support the solar panels in suitable sunlight."]


def generate_solar_consultation_form(seed):
    random.seed(seed)
    form = {}

    # Personal Information
    form["Name"] = fake.name()
    address = fake.address().replace('\n', ', ')
    state_abbr = address.split(' ')[-2].replace(",", "")
    files = [f for f in os.listdir('weather') if f.startswith(f'AUS_{state_abbr}')]
    form["Address"] = address
    form["Closest weather station (auto populated)"] = random.choice(files)
    form["Email"] = fake.email()
    form["Phone Number"] = fake.phone_number()

    # Property Information
    form["Property Address"] = form["Address"]
    form["Property Type"] = location_type
    form["Roof Type"] = "Metal"
    form["Property Shade"] = random.choice(["Yes", "No"])
    form["Roof Tilt (degrees)"] = random.randint(0, 45)
    form["Roof Azimuth (degrees)"] = random.randint(0, 360)

    # Energy Usage and Needs
    form["AC loads"] = ""
    form["AC Loads"] = list(ac_loads.items())
    form["DC loads"] = ""
    form["DC Loads"] = list(dc_loads.items())
    form["High Consumption Appliances"] = random.choice(["Yes", "No"])
    form["Future High Consumption Appliances"] = random.choice(["Yes", "No"])
    form["Critical Appliances"] = "Lights"
    form["Days of Autonomy"] = random.randint(2, 4)

    # Solar System Preferences
    form["Solar System Reason"] = random.choice(["Cost savings", "Energy independence", "Environmental reasons"])
    form["Solar System Type"] = "Off-grid"
    form["Budget"] = "Provide quote"
    form["Financing Options"] = random.choice(["Yes", "No"])

    # Additional Information
    return form

def export_to_pdf(form, filename):
    # Get a list of all files in the photo directory
    photo_files = os.listdir(f'photo_{location_type}')
    # Choose a random photo
    chosen_photo = random.choice(photo_files)

    # Open the photo and convert it to base64
    with open(f'photo_{location_type}/{chosen_photo}', 'rb') as img_file:
        img_base64 = base64.b64encode(img_file.read()).decode('utf-8')

    html = """
    <html>
    <head>
    <style>
    body {
        font-family: Arial, sans-serif;
    }
    h1 {
        color: #333;
    }
    table {
        width: 100%;
        border-collapse: collapse;
    }
    th, td {
        border: 1px solid #999;
        padding: 0.5rem;
        text-align: left;
    }
    th {
        background-color: #f3f3f3;
    }
    </style>
    </head>
    <body>
    <h1>Solar Consultation Form</h1>
    <img src="data:image/jpeg;base64,""" + img_base64 + """" style="max-width: 100%">
    <table>
    """

    for key, value in form.items():
        if isinstance(value, list):
            for item in value:
                # Assume item is a dictionary with the necessary keys
                # Add a print statement to see what item contains
                print(f"Item: {item[0]}")
    
                # Check if all expected keys are in the item dictionary
                if all(k in item[1] for k in ('power', 'winterusage', 'summerusage', 'remarks')):
                    # Safely extract information from the item
                    quantity = item[1]['quantity']
                    power = item[1]['power']

                    voltage_text = ""
                    if key == "DC Loads":
                        voltage = item[1]['voltage']
                        voltage_text = f"Voltage: {voltage}V, "
                        print(voltage_text)
                       
                    winterusage = item[1]['winterusage']
                    summerusage = item[1]['summerusage']
                    remarks = item[1]['remarks']  # or item.get('remarks', '') for a safe approach
    
                    # Add another print statement to check the variables before adding to HTML
                    #print(f"Adding to HTML: Name: {item[0]}, Quantity: {quantity}, Power: {power}, {voltage_text}Winter Usage: {winterusage}, Summer Usage: {summerusage}, Remarks: {remarks}")
    
                    # Append the item details to the HTML string
                    html += f"<tr><th>{item[0]}</th><td>Quantity: {quantity}, {power} watts, {voltage_text}{winterusage} minutes in winter, {summerusage} minutes in summer, remarks: {remarks}</td></tr>"
                else:
                    print("Some keys are missing in the item dictionary.")
        else:
            # Handle non-list values in the form dictionary
            html += f"<tr><th>{key}</th><td>{str(value)}</td></tr>"

# ... rest of the code ...

    html += """
    </table>

    </body>
    </html>
    """

    HTML(string=html).write_pdf(f"{location_type}/{filename}.pdf")

with open('student_list.csv', 'r') as f:
    reader = csv.reader(f)
    numbers = [int(row[0]) for row in reader]

location_types = ["farm", "residential home", "tourist lodge", "communication centre", "local workshop"]
for location_type in location_types:
    if location_type == "farm":
        ac_loads = {
        "Refrigerator": {"quantity": 1, "power": 150, "summerusage": 1440, "winterusage": 1440, "remarks": "average daily consumption 1200 Wh"},
        "Slow Cooker": {"quantity": 1, "power": 200, "summerusage": 480, "winterusage": 480, "remarks": "average daily consumption 1000 Wh"},
        "Dishwasher": {"quantity": 1, "power": 2000, "summerusage": 150, "winterusage": 150, "remarks": "average daily consumption 1000 Wh"},
        "Washing machine ": {"quantity": 1, "power": 2200, "summerusage": 120, "winterusage": 120, "remarks": "average daily consumption 800 Wh"},
        "Toaster Oven": {"quantity": 1, "power": 1500, "summerusage": 5, "winterusage": 5, "remarks": "None"},
        "Coffee Maker": {"quantity": 1, "power": 1500, "summerusage": 10, "winterusage": 12, "remarks": "None"},
        "Microwave": {"quantity": 1, "power": 1000, "summerusage": 8, "winterusage": 10, "remarks": "None"},
        "Television": {"quantity": 1, "power": 100, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        "Computer": {"quantity": 1, "power": 100, "summerusage": 120, "winterusage": 120, "remarks": "None"},
        "Well Pump": {"quantity": 1, "power": 750, "summerusage": 30, "winterusage": 30, "remarks": "None"},
        "Pressure Washer": {"quantity": 1, "power": 2000, "summerusage": 30, "winterusage": 30, "remarks": "None"},
        "Milking Machine": {"quantity": 1, "power": 1000, "summerusage": 30, "winterusage": 30, "remarks": "None"},
        "Egg Incubator": {"quantity": 1, "power": 60, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        "Circulation Fan": {"quantity": 1, "power": 250, "summerusage": 30, "winterusage": 20, "remarks": "None"},
        "Barn Ventilator": {"quantity": 1, "power": 250, "summerusage": 30, "winterusage": 30, "remarks": "None"},
        }
        
        dc_loads = {
        "Laptop ": {"quantity": 2, "power": 60, "voltage": 18, "summerusage": 480, "winterusage": 480, "remarks": "None"},
        "Phone Charger": {"quantity": 5, "power": 10, "voltage": 5, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Electric Fence": {"quantity": 1, "power": 20, "voltage": 24, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        "Walkie Talkies": {"quantity": 5, "power": 1, "voltage": 12, "summerusage": 480, "winterusage": 480, "remarks": "None"},
        "Flashlights charger": {"quantity": 2, "power": 5, "voltage": 12, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Fans": {"quantity": 1, "power": 30, "voltage": 12, "summerusage": 240, "winterusage": 30, "remarks": "None"},
        "Radios": {"quantity": 1, "power": 5, "voltage": 12, "summerusage": 240, "winterusage": 240, "remarks": "None"},
        "Yard Light": {"quantity": 1, "power": 100, "voltage": 12, "summerusage": 720, "winterusage": 840, "remarks": "None"},
        "Lights": {"quantity": 1, "power": 12, "voltage": 12, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        "Wifi router": {"quantity": 1, "power": 12, "voltage": 12, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        }

    if location_type == "residential home":
        ac_loads = {
        "Refrigerator": {"quantity": 1, "power": 150, "voltage": 240, "summerusage": 1440, "winterusage": 1440, "remarks": "average daily consumption 1200 Wh"},
        "Slow Cooker": {"quantity": 1, "power": 200, "voltage": 240, "summerusage": 480, "winterusage": 480, "remarks": "average daily consumption 1000 Wh"},
        "Dishwasher": {"quantity": 1, "power": 2000, "voltage": 240, "summerusage": 150, "winterusage": 150, "remarks": "average daily consumption 1000 Wh"},
        "Washing machine ": {"quantity": 1, "power": 2200, "voltage": 240, "summerusage": 120, "winterusage": 120, "remarks": "average daily consumption 800 Wh"},
        "Vacuum cleaner": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 3, "winterusage": 3, "remarks": "None"},
        "Toaster Oven": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 5, "winterusage": 5, "remarks": "None"},
        "Coffee Maker": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 10, "winterusage": 12, "remarks": "None"},
        "Microwave": {"quantity": 1, "power": 1000, "voltage": 240, "summerusage": 8, "winterusage": 10, "remarks": "None"},
        "Television": {"quantity": 1, "power": 100, "voltage": 240, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        }
        
        dc_loads = {
        "Laptop ": {"quantity": 2, "power": 60, "voltage": 18, "summerusage": 480, "winterusage": 480, "remarks": "None"},
        "Phone Charger": {"quantity": 5, "power": 10, "voltage": 5, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Flashlights charger": {"quantity": 2, "power": 5, "voltage": 12, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Fans": {"quantity": 2, "power": 30, "voltage": 12, "summerusage": 180, "winterusage": 15, "remarks": "None"},
        "Yard Light": {"quantity": 1, "power": 50, "voltage": 12, "summerusage": 720, "winterusage": 840, "remarks": "None"},
        "Lights": {"quantity": 2, "power": 12, "voltage": 12, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        "Wifi router": {"quantity": 1, "power": 12, "voltage": 12, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        }
    
    if location_type == "tourist lodge":
        ac_loads = {
        "Refrigerator": {"quantity": 1, "power": 150, "voltage": 240, "summerusage": 1440, "winterusage": 1440, "remarks": "average daily consumption 1200 Wh"},
        "Electric kettle": {"quantity": 2, "power": 1500, "voltage": 240, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Dishwasher": {"quantity": 1, "power": 2000, "voltage": 240, "summerusage": 300, "winterusage": 300, "remarks": "two cycles per day, average daily consumption 1000 Wh"},
        "Vacuum cleaner": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 30, "winterusage": 30, "remarks": "None"},
        "Coffee maker": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 60, "winterusage": 90, "remarks": "None"},
        "Television": {"quantity": 12, "power": 60, "voltage": 240, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        }
        
        dc_loads = {
        "Laptop ": {"quantity": 3, "power": 60, "voltage": 18, "summerusage": 120, "winterusage": 180, "remarks": "None"},
        "Phone Charger": {"quantity": 4, "power": 10, "voltage": 5, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Flashlights charger": {"quantity": 2, "power": 5, "voltage": 12, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Yard Light": {"quantity": 2, "power": 50, "voltage": 12, "summerusage": 720, "winterusage": 840, "remarks": "None"},
        "Lights": {"quantity": 20, "power": 12, "voltage": 12, "summerusage": 180, "winterusage": 240, "remarks": "None"},
        "Wifi router": {"quantity": 1, "power": 12, "voltage": 12, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        "Wifi booster": {"quantity": 4, "power": 12, "voltage": 12, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        }
    
    if location_type == "communication centre":
        ac_loads = {
        "Printer": {"quantity": 1, "power": 30, "voltage": 240, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Electric kettle": {"quantity": 1, "power": 1200, "voltage": 240, "summerusage": 10, "winterusage": 10, "remarks": "None"},
        "Vacuum cleaner": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 5, "winterusage": 5, "remarks": "None"},
        "Coffee maker": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 60, "winterusage": 90, "remarks": "None"},
        "Television": {"quantity": 1, "power": 60, "voltage": 240, "summerusage": 480, "winterusage": 480, "remarks": "None"},
        }
        
        dc_loads = {
        "Laptop ": {"quantity": 5, "power": 60, "voltage": 18, "summerusage": 480, "winterusage": 420, "remarks": "None"},
        "Phone Charger": {"quantity": 5, "power": 15, "voltage": 12, "summerusage": 240, "winterusage": 240, "remarks": "None"},
        "Yard Light": {"quantity": 1, "power": 50, "voltage": 12, "summerusage": 720, "winterusage": 840, "remarks": "None"},
        "Lights": {"quantity": 6, "power": 12, "voltage": 12, "summerusage": 480, "winterusage": 420, "remarks": "None"},
        "Wifi router": {"quantity": 1, "power": 12, "voltage": 12, "summerusage": 1440, "winterusage": 1440, "remarks": "None"},
        }
    
    if location_type == "local workshop":
        ac_loads = {
        "Grinder": {"quantity": 1, "power": 1000, "voltage": 240, "summerusage": 120, "winterusage": 120, "remarks": "grinder or welder or air blower used at a time"},
        "Welder": {"quantity": 1, "power": 750, "voltage": 240, "summerusage": 120, "winterusage": 120, "remarks": "grinder or welder or air blower used at a time"},
        "Air blower": {"quantity": 1, "power": 200, "voltage": 240, "summerusage": 20, "winterusage": 20, "remarks": "grinder or welder or air blower used at a time"},
        "Vacuum cleaner": {"quantity": 1, "power": 1500, "voltage": 240, "summerusage": 5, "winterusage": 5, "remarks": "None"}, 
        }
        
        dc_loads = {
        "Phone Charger": {"quantity": 1, "power": 10, "voltage": 12, "summerusage": 60, "winterusage": 60, "remarks": "None"},
        "Lights": {"quantity": 4, "power": 15, "voltage": 12, "summerusage": 480, "winterusage": 480, "remarks": "None"},
        }
    for number in numbers:
        form = generate_solar_consultation_form(number)
        export_to_pdf(form, number)
# Out:
# Item: Refrigerator
# Item: Slow Cooker
# Item: Dishwasher
# Item: Washing machine
# Item: Toaster Oven
# Item: Coffee Maker
# Item: Microwave
# Item: Television
# Item: Computer
# Item: Well Pump
# Item: Pressure Washer
# Item: Milking Machine
# Item: Egg Incubator
# Item: Circulation Fan
# Item: Barn Ventilator
# Item: Laptop
# Voltage: 18V,
# Item: Phone Charger
# Voltage: 5V,
# Item: Electric Fence
# Voltage: 24V,
# Item: Walkie Talkies
# Voltage: 12V,
# Item: Flashlights charger
# Voltage: 12V,
# Item: Fans
# Voltage: 12V,
# Item: Radios
# Voltage: 12V,
# Item: Yard Light
# Voltage: 12V,
# Item: Lights
# Voltage: 12V,
# Item: Wifi router
# Voltage: 12V,
# Item: Refrigerator
# Item: Slow Cooker
# Item: Dishwasher
# Item: Washing machine
# Item: Toaster Oven
# Item: Coffee Maker
# Item: Microwave
# Item: Television
# Item: Computer
# Item: Well Pump
# Item: Pressure Washer
# Item: Milking Machine
# Item: Egg Incubator
# Item: Circulation Fan
# Item: Barn Ventilator
# Item: Laptop
# ...
